# %%
# Named Entity Recognition with nltk
import nltk 
from nltk import word_tokenize,pos_tag,ne_chunk
from nltk.tree import Tree
input='Mahendra Singh Dhoni born 7 July 1981 is an Indian professional cricketer who plays as a right-handed batter and a wicket-keeper. Widely regarded as one of the most prolific wicket-keeper batsmen and captains and one of the greatest ODI batsmen ever, he represented the Indian cricket team and was the captain of the side in limited overs formats from 2007 to 2017 and in test cricket from 2008 to 2014. Dhoni has captained the most international matches and is the most successful Indian captain. He has led India to victory in the 2007 ICC World Twenty20, the 2011 Cricket World Cup, and the 2013 ICC Champions Trophy, being the only captain to win three different limited overs ICC tournaments. He also led the teams that won the Asia Cup in 2010, 2016 and was a member of the title winning squad in 2018.'
WT_text=word_tokenize(input)
ner= ne_chunk(pos_tag(WT_text))
named_ent = []
for subtree in ner:
     if isinstance(subtree,Tree):
         enty = " ".join([token for token,pos in subtree.leaves()])
         named_ent.append(enty)
print(named_ent)
print(ner)
# Out:
# ['Mahendra', 'Singh Dhoni', 'Indian', 'ODI', 'Indian', 'Dhoni', 'Indian', 'India', 'ICC', 'ICC', 'ICC', 'Asia']
# (S
#   (PERSON Mahendra/NNP)
#   (PERSON Singh/NNP Dhoni/NNP)
#   born/VBD
#   7/CD
#   July/NNP
#   1981/CD
#   is/VBZ
#   an/DT
#   (GPE Indian/JJ)
#   professional/JJ
#   cricketer/NN
#   who/WP
#   plays/VBZ
#   as/IN
#   a/DT
#   right-handed/JJ
#   batter/NN
#   and/CC
#   a/DT
#   wicket-keeper/JJ
#   ./.
#   Widely/RB
#   regarded/VBD
#   as/IN
#   one/CD
#   of/IN
#   the/DT
#   most/RBS
#   prolific/JJ
#   wicket-keeper/JJ
#   batsmen/NNS
#   and/CC
#   captains/NNS
#   and/CC
#   one/CD
#   of/IN
#   the/DT
#   greatest/JJS
#   (ORGANIZATION ODI/NN)
#   batsmen/NNS
#   ever/RB
#   ,/,
#   he/PRP
#   represented/VBD
#   the/DT
#   (GPE Indian/JJ)
#   cricket/NN
#   team/NN
#   and/CC
#   was/VBD
#   the/DT
#   captain/NN
#   of/IN
#   the/DT
#   side/NN
#   in/IN
#   limited/JJ
#   overs/NNS
#   formats/NNS
#   from/IN
#   2007/CD
#   to/TO
#   2017/CD
#   and/CC
#   in/IN
#   test/NN
#   cricket/NN
#   from/IN
#   2008/CD
#   to/TO
#   2014/CD
#   ./.
#   (PERSON Dhoni/NNP)
#   has/VBZ
#   captained/VBN
#   the/DT
#   most/RBS
#   international/JJ
#   matches/NNS
#   and/CC
#   is/VBZ
#   the/DT
#   most/RBS
#   successful/JJ
#   (GPE Indian/JJ)
#   captain/NN
#   ./.
#   He/PRP
#   has/VBZ
#   led/VBN
#   (GPE India/NNP)
#   to/TO
#   victory/NN
#   in/IN
#   the/DT
#   2007/CD
#   (ORGANIZATION ICC/NNP)
#   World/NNP
#   Twenty20/NNP
#   ,/,
#   the/DT
#   2011/CD
#   Cricket/NNP
#   World/NNP
#   Cup/NNP
#   ,/,
#   and/CC
#   the/DT
#   2013/CD
#   (ORGANIZATION ICC/NNP)
#   Champions/NNP
#   Trophy/NNP
#   ,/,
#   being/VBG
#   the/DT
#   only/RB
#   captain/NN
#   to/TO
#   win/VB
#   three/CD
#   different/JJ
#   limited/VBD
#   overs/NNS
#   (ORGANIZATION ICC/NNP)
#   tournaments/NNS
#   ./.
#   He/PRP
#   also/RB
#   led/VBD
#   the/DT
#   teams/NNS
#   that/WDT
#   won/VBD
#   the/DT
#   (GPE Asia/NNP)
#   Cup/NNP
#   in/IN
#   2010/CD
#   ,/,
#   2016/CD
#   and/CC
#   was/VBD
#   a/DT
#   member/NN
#   of/IN
#   the/DT
#   title/NN
#   winning/VBG
#   squad/NN
#   in/IN
#   2018/CD
#   ./.)

# %%
# Named Entity Recognition with spacy
import spacy
input='Mahendra Singh Dhoni born 7 July 1981 is an Indian professional cricketer who plays as a right-handed batter and a wicket-keeper. Widely regarded as one of the most prolific wicket-keeper batsmen and captains and one of the greatest ODI batsmen ever, he represented the Indian cricket team and was the captain of the side in limited overs formats from 2007 to 2017 and in test cricket from 2008 to 2014. Dhoni has captained the most international matches and is the most successful Indian captain. He has led India to victory in the 2007 ICC World Twenty20, the 2011 Cricket World Cup, and the 2013 ICC Champions Trophy, being the only captain to win three different limited overs ICC tournaments. He also led the teams that won the Asia Cup in 2010, 2016 and was a member of the title winning squad in 2018.'
nlp=spacy.load("en_core_web_sm")
doc=nlp(input)
named_ent=[]
for ent in doc.ents:
    named_ent.append((ent.text,ent.label_))
print (named_ent)
# Out:
# [('Mahendra Singh Dhoni', 'PERSON'), ('7 July 1981', 'DATE'), ('Indian', 'NORP'), ('ODI', 'ORG'), ('Indian', 'NORP'), ('2007', 'DATE'), ('2017', 'DATE'), ('2008', 'DATE'), ('2014', 'DATE'), ('Dhoni', 'PERSON'), ('Indian', 'NORP'), ('India', 'GPE'), ('2007', 'DATE'), ('ICC World Twenty20', 'EVENT'), ('the 2011 Cricket World Cup', 'ORG'), ('2013', 'DATE'), ('three', 'CARDINAL'), ('the Asia Cup', 'EVENT'), ('2010', 'DATE'), ('2016', 'DATE'), ('2018', 'DATE')]
